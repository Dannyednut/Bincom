# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

scores = pd.read_csv('student_scores.csv')

df = pd.DataFrame(scores)

df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
df['Scores'].max()
# Out:
# 95

# %%
df['Scores'].min()
# Out:
# 17

# %%
df['Scores'].mean()
# Out:
# 51.48

# %%
sns.barplot(df, x='Scores', y='Hours')
# Out:
# <Axes: xlabel='Scores', ylabel='Hours'>

# %%
sns.scatterplot(df, x='Scores', y='Hours')
# Out:
# <Axes: xlabel='Scores', ylabel='Hours'>
